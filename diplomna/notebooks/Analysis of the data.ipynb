# %%
import pandas as pd

# %%
data = pd.read_json("../scripts/transcripts/data.json")

# %%
data.head()
# Out:
#    duration  start                                     text
# 0     4.109   1.04                            from NBC News
# 1     7.200   6.66     decision 2016 the first presidential
# 2     6.660  10.32   debate live from Hofstra University in
# 3     7.530  13.86     Hempstead New York here now Savannah
# 4     6.539  16.98  Guthrie and Chuck Todd and good evening

# %%
whole_text = '\n'.join(data['text'].values.tolist())

# %%
print(whole_text)
# Out:
# from NBC News
# decision 2016 the first presidential
# debate live from Hofstra University in
# Hempstead New York here now Savannah
# Guthrie and Chuck Todd and good evening
# everybody nice to have you with us Chuck
# after all the hype all the prep all the
# pre debate gamesmanship from both
# campaigns this is it we are literally
# just minutes away now from the start of
# this first and all important
# presidential debate on the stage behind
# us we've already seen the candidates
# tonight Hillary Clinton and Donald Trump
# each arriving here a bit earlier this
# evening they're waiting backstage and
# Chuck we've had a moment tonight
# President Bill Clinton is in the house
# and met mrs. Melania Trump and they just
# shared that handshake we've got the
# whole families assembled here we do and
# I think one thing we had to remember as
# big of personalities that they are and
# we know this was going to be a clash of
# big personalities this is also a clash
# ...

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
from scripts.search_rev import info_search_in_rev

# %%
data = pd.read_csv("../dataset/search_queries.txt", names=['search_queries', 'is_available'])

# %%
data.head()
# Out:
#                          search_queries is_available
# 0  2012/10/23 third presidential debate           no
# 1              2015/08/05 GOP cleveland          yes
# 2        2015/10/13 democrats las vegas           no
# 3                2015/10/28 GOP boulder           no
# 4              2015/11/10 GOP milwuakee          NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 2 columns):
# search_queries    83 non-null object
# is_available      46 non-null object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
data['is_available'].str.lower().str.contains('yes').sum()
# Out:
# 39

# %%
data['rev_search'] = data.apply(lambda x: info_search_in_rev(x['search_queries'].split(' ')), axis=1)

# %%
data.head(20)
# Out:
#                               search_queries  \
# 0       2012/10/23 third presidential debate
# 1                   2015/08/05 GOP cleveland
# 2             2015/10/13 democrats las vegas
# 3                     2015/10/28 GOP boulder
# 4                   2015/11/10 GOP milwuakee
# 5        2016/01/12 Obama state of the union
# 6   2016/01/12 rick scott state of the state
# 7                  2016/01/15 GOP charleston
# 8            2016/01/17 democrats charleston
# 9         2016/02/04 democrats new hampshire
# 10            2016/02/11 democrats milwuakee
# 11                 2016/02/13 GOP greenville
# 12                      2016/02/25 GOP texas
# 13                   2016/03/03 GOP michigan
# 14                2016/03/07 democrats flint
# 15                2016/03/09 democrats miami
# 16                      2016/03/11 GOP miami
# 17               2016/03/29 kasich milwuakee
# 18                  2016/03/31 Cruz Miluakee
# 19                2016/04/01 Trump Milwaukee
#
# ...
